# %%
import pandas as pd
from sklearn.preprocessing import  StandardScaler
import numpy as np

# %%
df = pd.read_csv("./dataset/dataset.csv", index_col=0)

# %%
new_list = [column.title() for column in df.columns]
print(new_list)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Marketcap', 'Timestamp', 'Crypto_Name', 'Date']

# %%
df.columns = new_list
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Marketcap', 'Timestamp',
#        'Crypto_Name', 'Date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Open           float64
# High           float64
# Low            float64
# Close          float64
# Volume         float64
# Marketcap      float64
# Timestamp       object
# Crypto_Name     object
# Date            object
# dtype: object

# %%
df.describe()
df.shape
# Out:
# (72946, 9)

# %%
df.Marketcap
np.isinf(df.Marketcap).any()
# Out:
# np.False_

# %%
std_scaler = StandardScaler()


x = std_scaler.fit_transform(df[['Marketcap']])
x
# Out:
# array([[-0.1794472 ],
#        [-0.19579672],
#        [-0.17997606],
#        ...,
#        [-0.1758363 ],
#        [-0.17561313],
#        [ 0.11530903]], shape=(72946, 1))
